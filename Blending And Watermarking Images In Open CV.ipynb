# %%
#Import the necessary libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#convertBGR2GRAY
img1 = cv2.imread('Mustang.jpg' )
img_rgb = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb);

# %%
# Check data type of original image  
print('image dtype ',img_rgb.dtype)
# Out:
# image dtype  uint8

# %%
# Notice the usage of shape attribute to create image of exact same size. Zeros is to create a black image    
blank_img = np.zeros(shape=(img_rgb.shape[0],img_rgb.shape[1],3), dtype=np.uint8)

# %%
# notice flip of x and y or org with image shape
font = cv2.FONT_HERSHEY_SIMPLEX  
cv2.putText(blank_img,  
            text='Mustang Hotel',  
            org=(img_rgb.shape[1]//8, img_rgb.shape[0]//2),   
            fontFace=font,  
            fontScale= 10,color=(255,0,0),  
            thickness=10,  
            lineType=cv2.LINE_4)  
plt.imshow(blank_img);

# %%
# original image is made a little light and watermark dark  
blended = cv2.addWeighted(src1=img_rgb,alpha=0.7,src2=blank_img,beta=1, gamma = 0)  
plt.imshow(blended);

# %%
# make sure to use the correct color channels  
cv2.imwrite('Mustang_watermarked.jpg', cv2.cvtColor(blended, cv2.COLOR_RGB2BGR))
# Out:
# True
